# %% [markdown]
# ### NLP Classification of MOF Literature for CO₂ Adsorption
# ``` text
# Scientific abstract or paragraph
#               ↓
#         NLP model
#               ↓
# CO₂-adsorption relevant / not relevant
#
# # workflow
#
# MOF–CO₂ literature
#         ↓
# Create question–answer pairs
#         ↓
# Pretrained LLM
#         ↓
# Fine-tune on MOF QA
#         ↓
# MOF-specialized LLM
#         ↓
# Evaluate questions
#         ↓
# Later add RAG (knowledge-graph–based retrieval-augmented generation)
